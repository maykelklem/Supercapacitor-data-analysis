# %%
import pandas as pd

df_gcd = pd.read_csv("teste_GCD.csv")

df_gcd
# Out:
#        Time (s)  Voltage (V)
# 0      0.000004     0.030686
# 1      0.000204     0.030525
# 2      0.001004     0.031752
# 3      0.002004     0.033050
# 4      0.003204     0.034157
# ...         ...          ...
# 1472  49.181403     0.002122
# 1473  49.240803     0.001110
# 1474  49.306003     0.000079
# 1475  49.312603    -0.000054
# 1476  49.312803     0.000022
#
# [1477 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

df_gcd.plot(x="Time (s)", y="Voltage (V)")
plt.title("Galvanostatic Charge/Discharge")
plt.xlabel("Time (s)")
plt.ylabel("Voltage (V)")
plt.show()

# %%
max_volt_index = df_gcd["Voltage (V)"].idxmax()

print(max_volt_index)

initial_voltage = df_gcd["Voltage (V)"][max_volt_index + 2]

initial_voltage
# Out:
# 735
# 0.769830882549286

# %%
final_voltage = df_gcd["Voltage (V)"].iloc[-1]

final_voltage
# Out:
# 2.20395741052926e-05

# %%
initial_time = df_gcd.loc[max_volt_index, 'Time (s)']

initial_time
# Out:
# 25.8674030975953

# %%
final_time = df_gcd["Time (s)"].iloc[-1]

final_time
# Out:
# 49.3128025053001

# %%
discharge_current = (50e-6)

capacitance = (discharge_current*(final_time - initial_time))/(initial_voltage - final_voltage)

print(f"The device's capacitance is {capacitance} Farads")
# Out:
# The device's capacitance is 0.0015228065786495972
